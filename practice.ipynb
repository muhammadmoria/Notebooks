# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("loan.csv")

# %%
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
data.shape
# Out:
# (614, 13)

# %%
data.isnull().sum().sum()/(data.shape[0]*data.shape[1])*100
# Out:
# 1.8667000751691305

# %%
#1.866 percent data is null in loan data set

# %%
sns.heatmap(data.isnull() )
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#98.133 percent data is not null  in this data set.

# %%
data.notnull().sum().sum()/(data.shape[0]*data.shape[1])*100
# Out:
# 98.13329992483088

# %%
data.value_counts
# Out:
# <bound method DataFrame.value_counts of       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
sns.heatmap(data.notnull())
plt.show()

# %%
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data.drop(["Credit_History"],axis=1,inplace=True)

# %%
data.notnull().sum().sum()/(data.shape[0]*data.shape[1])*100
# Out:
# 99.2671009771987

# %%
data["Self_Employed"].backfill(inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_968\1866472354.py:1: FutureWarning: DataFrame.backfill/Series.backfill is deprecated. Use DataFrame.bfill/Series.bfill instead
#   data["Self_Employed"].backfill(inplace=True)

# %%
data["Self_Employed"].isnull().sum()
# Out:
# 0

# %%
data["Gender"].ffill(inplace=True)

# %%
data["Gender"].isnull().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
data["Married"].backfill(inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_968\2328090523.py:1: FutureWarning: DataFrame.backfill/Series.backfill is deprecated. Use DataFrame.bfill/Series.bfill instead
#   data["Married"].backfill(inplace=True)

# %%
data["Dependents"].backfill(inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_968\3381136013.py:1: FutureWarning: DataFrame.backfill/Series.backfill is deprecated. Use DataFrame.bfill/Series.bfill instead
#   data["Dependents"].backfill(inplace=True)

# %%
data
# Out:
# list

# %%
data["LoanAmount"].fillna(data.LoanAmount.mean,inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_968\2229211973.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '<bound method Series.mean of 0        NaN
# 1      128.0
# 2       66.0
# 3      120.0
# 4      141.0
#        ...
# 609     71.0
# 610     40.0
# 611    253.0
# 612    187.0
# 613    133.0
# Name: LoanAmount, Length: 614, dtype: float64>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data["LoanAmount"].fillna(data.LoanAmount.mean,inplace=True)

# %%
# Out:
# 0      360.0
# 1      360.0
# 2      360.0
# 3      360.0
# 4      360.0
#        ...
# 609    360.0
# 610    180.0
# 611    360.0
# 612    360.0
# 613    360.0
# Name: Loan_Amount_Term, Length: 614, dtype: float64

# %%
data["Loan_Amount_Term"].backfill(inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_968\516629307.py:1: FutureWarning: DataFrame.backfill/Series.backfill is deprecated. Use DataFrame.bfill/Series.bfill instead
#   data["Loan_Amount_Term"].backfill(inplace=True)

# %%
data.notnull().sum().sum()/(data.shape[0]*data.shape[1])*100
# Out:
# 100.0

# %%
#now both are looking on only one colour.

# %%
sns.heatmap(data.notnull())
plt.show()

# %%
sns.heatmap(data.isnull())
plt.show()

# %%
try:
    data.plot.pie()
except Exception as e :
    print(e)
    plt.show()
# Out:
# pie requires either y column or 'subplots=True'

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
plt.plot(data.Gender)
